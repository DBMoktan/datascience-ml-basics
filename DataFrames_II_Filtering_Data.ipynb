# %% [markdown]
# # DataFrames II: Filtering Data

# %%
import pandas as pd

# %% [markdown]
# ## This Module's Dataset + Memory Optimization
# - The `pd.to_datetime` method converts a **Series** to hold datetime values.
# - The `format` parameter informs pandas of the format that the times are stored in.
# - We pass symbols designating the segments of the string. For example, %m means "month" and %d means day.
# - The `dt` attribute reveals an object with many datetime-related attributes and methods.
# - The `dt.time` attribute extracts only the time from each value in a datetime **Series**.
# - Use the `astype` method to convert the values in a **Series** to another type.
# - The `parse_dates` parameter of `read_csv` is an alternate way to parse strings as datetimes.

# %%
employees = pd.read_csv("employees.csv")

# %%
employees
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
employees.dtypes
# Out:
# First Name            object
# Gender                object
# Start Date            object
# Last Login Time       object
# Salary                 int64
# Bonus %              float64
# Senior Management     object
# Team                  object
# dtype: object

# %%
employees.sample(4)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 862     Ronald    Male  5/25/1983        10:05 AM   50426   18.536
# 135     Gloria  Female  6/29/2007         5:34 AM  134148    8.833
# 313       Judy  Female   7/1/1991         2:33 AM  109510   13.457
# 370      Linda  Female  7/15/2009        10:12 PM  144001    2.194
#
#     Senior Management                  Team
# 862              True                 Sales
# 135              True                 Legal
# 313              True                 Legal
# 370             False  Business Development

# %%
employees.head(4)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance
# 3              True    Finance

# %%
employees.tail(4)
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 996    Phillip   Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell   Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry   Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert   Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales

# %%
employees.dtypes
# Out:
# First Name            object
# Gender                object
# Start Date            object
# Last Login Time       object
# Salary                 int64
# Bonus %              float64
# Senior Management     object
# Team                  object
# dtype: object

# %%
employees["Start Date"] = pd.to_datetime(employees["Start Date"], format="%m/%d/%Y")

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 62.6+ KB

# %%
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4      Larry    Male 1998-01-24         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
employees['Last Login Time'].head()
# Out:
# 0    12:42 PM
# 1     6:53 AM
# 2    11:17 AM
# 3     1:00 PM
# 4     4:47 PM
# Name: Last Login Time, dtype: object

# %%
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p").dt.time

# %%
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
employees["Senior Management"].unique()
# Out:
# array([True, False, nan], dtype=object)

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 62.6+ KB

# %%
employees['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
employees['Senior Management'].unique()
# Out:
# array([True, False, nan], dtype=object)

# %%
employees["Senior Management"] = employees["Senior Management"].astype(bool)

# %%
employees["Gender"] = employees["Gender"].astype("category")

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 49.1+ KB

# %%
employees.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management      0
# Team                  43
# dtype: int64

# %%
49.1/62.6
# Out:
# 0.7843450479233227

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p").dt.time
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
employees.dtypes
# Out:
# First Name                   object
# Gender                       object
# Start Date           datetime64[ns]
# Last Login Time              object
# Salary                        int64
# Bonus %                     float64
# Senior Management            object
# Team                         object
# dtype: object

# %% [markdown]
# ## Filter A DataFrame  Based On A Condition
# - Pandas needs a **Series** of Booleans to perform a filter.
# - Pass the Boolean Series inside square brackets after the **DataFrame**.
# - We can generate a Boolean Series using a wide variety of operations (equality, inequality, less than, greater than, inclusion, etc)

# %%
import pandas as pd

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p").dt.time
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
import datetime as dt

# %%
employees.tail()
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 995      Henry    NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip   Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert   Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales

# %%
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees['Gender'] == 'Male'
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
employees[employees["Gender"] == "Male"]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31        06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry   Male 1998-01-24        04:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18        01:35:00  115163   10.125
# ..         ...    ...        ...             ...     ...      ...
# 994     George   Male 2013-06-21        05:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert   Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [424 rows x 8 columns]

# %%
employees[employees["Gender"] == "Female"]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22        06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08        06:51:00  139852    7.524
# ..         ...     ...        ...             ...     ...      ...
# 987     Gloria  Female 2014-12-08        05:08:00  136709   10.331
# 988      Alice  Female 2004-10-05        09:34:00   47638   11.209
# 990      Robin  Female 1987-07-24        01:35:00  100765   10.982
# 991       Rose  Female 2002-08-25        05:12:00  134505   11.051
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
#
#      Senior Management                  Team
# 2                False               Finance
# 6                 True               Product
# 7                 True               Finance
# 8                 True           Engineering
# 9                 True  Business Development
# ..                 ...                   ...
# 987               True               Finance
# 988              False       Human Resources
# 990               True       Client Services
# 991               True             Marketing
# 993               True           Engineering
#
# [431 rows x 8 columns]

# %%
employees['Gender'].unique()
# Out:
# ['Male', 'Female', NaN]
# Categories (2, object): ['Female', 'Male']

# %%
employees.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees[employees["Gender"] == "Female"]

employees[employees["Team"] == "Finance"]

on_finance_team = employees["Team"] == "Finance"

employees[on_finance_team]

employees[employees["Senior Management"] == True]
employees[employees["Senior Management"] == True].head()

employees[employees["Salary"] > 148500]

employees[employees["Bonus %"] > 19.75]

employees[employees["Start Date"] < "1980-03-01"].sort_values("Start Date")

employees[employees["Last Login Time"] < dt.time(12, 0, 0)]

employees[employees['First Name'] == 'Donald']
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 506     Donald   Male 1995-07-14        07:51:00  106472    6.499
# 647     Donald   Male 1988-04-06        10:00:00  122920    5.320
# 909     Donald   Male 1991-08-01        02:25:00   61999    6.466
#
#      Senior Management             Team
# 506               True  Client Services
# 647              False              NaN
# 909              False          Product

# %%
employees.dtypes
# Out:
# First Name                   object
# Gender                     category
# Start Date           datetime64[ns]
# Last Login Time              object
# Salary                        int64
# Bonus %                     float64
# Senior Management              bool
# Team                         object
# dtype: object

# %% [markdown]
# ## Filter with More than One Condition (AND)
# - Add the `&` operator in between two Boolean **Series** to filter by multiple conditions.
# - We can assign the **Series** to variables to make the syntax more readable.

# %%
import pandas as pd

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p").dt.time
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees.dtypes
# Out:
# First Name                   object
# Gender                     category
# Start Date           datetime64[ns]
# Last Login Time              object
# Salary                        int64
# Bonus %                     float64
# Senior Management              bool
# Team                         object
# dtype: object

# %%
# female employees who work in Finance and Senior Management who earn over $130k a year with bonus percentage above 10
# so we need to use & operator
is_female = employees["Gender"] == "Female"
is_in_finance = employees["Team"] == "Finance"
salary_over_130k = employees["Salary"] > 130000
is_in_senior_management = employees["Senior Management"]
bonus_above_10 = employees['Bonus %'] > 10

# %%
is_female
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Gender, Length: 1000, dtype: bool

# %%
# is_female & is_in_finance & salary_over_130k & is_in_senior_management & bonus_above_10
employees[is_female & is_in_finance & salary_over_130k & is_in_senior_management & bonus_above_10]
# True, True -> True
# True, False -> False
# False, True -> False
# False, False -> False
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 160      Kathy  Female 2000-03-18        07:26:00  149563   16.991
# 987     Gloria  Female 2014-12-08        05:08:00  136709   10.331
#
#      Senior Management     Team
# 160               True  Finance
# 987               True  Finance

# %%
employees.dtypes
# Out:
# First Name                   object
# Gender                     category
# Start Date           datetime64[ns]
# Last Login Time              object
# Salary                        int64
# Bonus %                     float64
# Senior Management              bool
# Team                         object
# dtype: object

# %%
bonus_above_8 = employees["Bonus %"] >= 8

# %%
employees[is_female & is_in_finance & salary_over_130k & bonus_above_8]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 103    Phyllis  Female 1996-10-11        09:30:00  136984    8.932
# 160      Kathy  Female 2000-03-18        07:26:00  149563   16.991
# 526    Barbara  Female 2004-03-22        08:11:00  144677    8.696
# 644  Katherine  Female 1996-08-13        12:21:00  149908   18.912
# 907  Elizabeth  Female 1998-07-27        11:12:00  137144   10.081
# 987     Gloria  Female 2014-12-08        05:08:00  136709   10.331
#
#      Senior Management     Team
# 2                False  Finance
# 103               True  Finance
# 160               True  Finance
# 526              False  Finance
# 644              False  Finance
# 907              False  Finance
# 987               True  Finance

# %%
not_senior_management = employees["Senior Management"] == False
employees[is_female & is_in_finance & salary_over_130k & bonus_above_8 & not_senior_management]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 526    Barbara  Female 2004-03-22        08:11:00  144677    8.696
# 644  Katherine  Female 1996-08-13        12:21:00  149908   18.912
# 907  Elizabeth  Female 1998-07-27        11:12:00  137144   10.081
#
#      Senior Management     Team
# 2                False  Finance
# 526              False  Finance
# 644              False  Finance
# 907              False  Finance

# %% [markdown]
# ## Filter with More than One Condition (OR)
# - Use the `|` operator in between two Boolean **Series** to filter by *either* condition.

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p").dt.time
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
# AND vs OR (OR logic below)

# True, True -> True
# True, False -> True
# False, True -> True
# False, False -> False

# Employees who are either senior management OR started before January 1st, 1990

is_senior_management = employees["Senior Management"] == True
started_in_80s = employees["Start Date"] < "1990-01-01"

employees[is_senior_management | started_in_80s]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 5                False            Legal
# ..                 ...              ...
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 996              False          Finance
# 999               True            Sales
#
# [653 rows x 8 columns]

# %%
# First name is robert and works in client services
employees[(employees['First Name'] == 'Robert') & (employees['Team'] == 'Client Services')]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 387     Robert   Male 1994-10-29        04:26:00  123294   19.894
#
#      Senior Management             Team
# 387              False  Client Services

# %%
# First Name is Robert who work in Client Services OR Start Date after 2016-06-01

# %%
is_robert = employees["First Name"] == "Robert"
is_in_client_services = employees["Team"] == "Client Services"
start_date_after_june_2016 = employees["Start Date"] > "2016-06-01"

# %%
employees[is_robert & start_date_after_june_2016]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
employees[is_robert | start_date_after_june_2016]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16        07:47:00  100705   16.961
# 242     Robert    Male 1990-10-27        07:15:00   38041   18.428
# 335     Robert    Male 2014-11-18        05:00:00   85799   19.930
# 387     Robert    Male 1994-10-29        04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15        12:29:00  140002   19.490
# 488     Robert    Male 2007-03-11        11:20:00  135882   19.944
# 672     Robert    Male 1982-11-05        12:41:00  111580   10.982
# 825     Robert     NaN 2000-12-04        01:20:00   69267    5.890
# 880     Robert     NaN 2007-05-25        03:17:00   90998    8.382
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 242               True      Engineering
# 335              False          Finance
# 387              False  Client Services
# 451               True        Marketing
# 488              False            Legal
# 672              False  Human Resources
# 825               True            Sales
# 880              False          Finance

# %% [markdown]
# ## The isin Method
# - The `isin` **Series** method accepts a collection object like a list, tuple, or **Series**.
# - The method returns True for a row if its value is found in the collection.

# %%
import pandas as pd

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p").dt.time
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
# Legal Team or Sales Team or Product Team

legal_team = employees["Team"] == "Legal"
sales_team = employees["Team"] == "Sales"
product_team = employees["Team"] == "Product"
employees[legal_team | sales_team | product_team]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 11       Julie  Female 1997-10-26        03:19:00  102508   12.637
# 13        Gary    Male 2008-01-27        11:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# ..         ...     ...        ...             ...     ...      ...
# 981      James    Male 1993-01-15        05:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10        08:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10        04:58:00   38344    3.794
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %%
target_teams = employees["Team"].isin(["Legal", "Sales", "Product"])
employees[target_teams]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 11       Julie  Female 1997-10-26        03:19:00  102508   12.637
# 13        Gary    Male 2008-01-27        11:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# ..         ...     ...        ...             ...     ...      ...
# 981      James    Male 1993-01-15        05:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10        08:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10        04:58:00   38344    3.794
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %% [markdown]
# ## The isnull and notnull Methods
# - The `isnull` method returns True for `NaN` values in a **Series**.
# - The `notnull` method returns True for present values in a **Series**.

# %%
import pandas as pd

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p").dt.time
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees.tail()
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 995      Henry    NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip   Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert   Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales

# %%
employees.isnull()
employees['Gender'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Gender, Length: 1000, dtype: bool

# %%
employees[employees['Gender'].isnull()]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 20        Lois    NaN 1995-04-22        07:18:00   64714    4.934
# 22      Joshua    NaN 2012-03-08        01:58:00   90816   18.816
# 27       Scott    NaN 1991-07-11        06:58:00  122367    5.218
# 31       Joyce    NaN 2005-02-20        02:40:00   88657   12.752
# 41   Christine    NaN 2015-06-28        01:08:00   66582   11.308
# ..         ...    ...        ...             ...     ...      ...
# 961    Antonio    NaN 1989-06-18        09:37:00  103050    3.050
# 972     Victor    NaN 2006-07-28        02:49:00   76381   11.159
# 985    Stephen    NaN 1983-07-10        08:10:00   85668    1.909
# 989     Justin    NaN 1991-02-10        04:58:00   38344    3.794
# 995      Henry    NaN 2014-11-23        06:09:00  132483   16.655
#
#      Senior Management                  Team
# 20                True                 Legal
# 22                True       Client Services
# 27               False                 Legal
# 31               False               Product
# 41                True  Business Development
# ..                 ...                   ...
# 961              False                 Legal
# 972               True                 Sales
# 985              False                 Legal
# 989              False                 Legal
# 995              False          Distribution
#
# [145 rows x 8 columns]

# %%
employees[employees["Team"].isnull()]

employees[employees["Team"].notnull()]

employees[employees["First Name"].isnull() & employees["Team"].notnull()]

employees[employees['Salary'].notnull() & employees['First Name'].notnull()]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [933 rows x 8 columns]

# %% [markdown]
# ## The between Method
# - The `between` method returns True if a **Series** value is found within its range.

# %%
import pandas as pd

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p").dt.time
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
import datetime as dt

# %%
employees[(employees['Salary'] >= 60000) & (employees['Salary'] <= 70000)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 10      Louise  Female 1980-08-12        09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22        07:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28        01:08:00   66582   11.308
# ..         ...     ...        ...             ...     ...      ...
# 965  Catherine  Female 1989-09-25        01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03        08:54:00   63571   15.397
# 974      Harry    Male 2011-08-30        06:31:00   67656   16.455
# 978       Sean    Male 1983-01-17        02:23:00   66146   11.178
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# 6                 True               Product
# 10                True                   NaN
# 20                True                 Legal
# 41                True  Business Development
# ..                 ...                   ...
# 965              False       Client Services
# 970               True               Product
# 974               True       Client Services
# 978              False       Human Resources
# 998              False  Business Development
#
# [86 rows x 8 columns]

# %%
employees[employees["Salary"].between(60000, 70000)]

employees[employees["Bonus %"].between(2.0, 5.0)]

employees[employees["Start Date"].between("1992-01-01", "1993-01-01")]

employees[employees["Last Login Time"].between(dt.time(6, 00), dt.time(7, 00))]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 8       Angela  Female 2005-11-22        06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08        06:51:00  139852    7.524
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# 27       Scott     NaN 1991-07-11        06:58:00  122367    5.218
# ..         ...     ...        ...             ...     ...      ...
# 974      Harry    Male 2011-08-30        06:31:00   67656   16.455
# 979     Ernest    Male 2013-07-20        06:41:00  142935   13.198
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 1                 True                   NaN
# 8                 True           Engineering
# 9                 True  Business Development
# 15               False               Product
# 27               False                 Legal
# ..                 ...                   ...
# 974               True       Client Services
# 979               True               Product
# 995              False          Distribution
# 996              False               Finance
# 999               True                 Sales
#
# [101 rows x 8 columns]

# %% [markdown]
# ## The duplicated Method
# - The `duplicated` method returns True if a **Series** value is a duplicate.
# - Pandas will mark one occurrence of a repeated value as a non-duplicate.
# - Use the `keep` parameter to designate whether the first or last occurrence of a repeated value should be considered the "non-duplicate".
# - Pass False to the `keep` parameter to mark all occurrences of repeated values as duplicates.
# - Use the tilde symbol (`~`) to invert a **Series's** values. Trues will become Falses, and Falses will become trues.

# %%
import pandas as pd

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p").dt.time
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
employees[employees['First Name'] == 'Henry']
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 57       Henry   Male 1996-06-26        01:44:00   64715   15.107
# 136      Henry   Male 1995-04-24        04:18:00   43542   19.687
# 259      Henry   Male 1995-02-06        08:34:00   89258   15.585
# 732      Henry   Male 1986-05-12        02:04:00   59943    1.432
# 752      Henry   Male 2007-02-23        03:24:00   49665   18.338
# 995      Henry    NaN 2014-11-23        06:09:00  132483   16.655
#
#      Senior Management                  Team
# 57                True       Human Resources
# 136              False                 Legal
# 259               True       Human Resources
# 732              False               Finance
# 752              False  Business Development
# 995              False          Distribution

# %%
employees['First Name'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: First Name, Length: 1000, dtype: bool

# %%
employees[employees["First Name"].duplicated()]
employees[employees["First Name"].duplicated(keep="first")]

employees[employees["First Name"].duplicated(keep="last")]

employees[employees["First Name"].duplicated(keep=False)]

employees[employees["Gender"].duplicated(keep='first')]

employees[employees["Gender"].duplicated(keep=False)]

employees[~employees["Gender"].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %% [markdown]
# ## The drop_duplicates Method
# - The `drop_duplicates` method deletes rows with duplicate values.
# - By default, it will remove a row if *all* of its values are shared with another row.
# - The `subset` parameter configures the columns to look for duplicate values within.
# - Pass a list to `subset` parameter to look for duplicates across multiple columns.

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p").dt.time
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees.drop_duplicates("Team")
employees.drop_duplicates("Team", keep="first")
employees.drop_duplicates("Team", keep="last")
employees.drop_duplicates("Team", keep=False)

employees.drop_duplicates("First Name", keep=False)

employees.drop_duplicates()

employees.drop_duplicates(subset = ["Senior Management", "Team"])

employees.drop_duplicates(["Senior Management", "Team", "Gender"], keep = 'last')
employees.drop_duplicates(["Senior Management", "Team", "Gender"], keep = False)
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 91       James    NaN 2005-01-26        11:00:00  128771    8.309
# 456    Deborah    NaN 1983-02-03        11:38:00  101457    6.662
#
#      Senior Management         Team
# 91               False          NaN
# 456              False  Engineering

# %% [markdown]
# ## The unique and nunique Methods
# - The `unique` method on a **Series** returns a collection of its unique values. The method does not exist on a **DataFrame**.
# - The `nunique` method returns a *count* of the number of unique values in the **Series**/**DataFrame**.
# - The `dropna` parameter configures whether to include or exclude missing (`NaN`) values.

# %%
import pandas as pd

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p").dt.time
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees.dtypes
# Out:
# First Name                   object
# Gender                     category
# Start Date           datetime64[ns]
# Last Login Time              object
# Salary                        int64
# Bonus %                     float64
# Senior Management              bool
# Team                         object
# dtype: object

# %%
employees.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1794/4224533988.py in <cell line: 0>()
# ----> 1 employees.unique()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
employees['Gender'].unique()
# Out:
# ['Male', 'Female', NaN]
# Categories (2, object): ['Female', 'Male']

# %%
employees.nunique()
# Out:
# First Name           200
# Gender                 2
# Start Date           972
# Last Login Time      542
# Salary               995
# Bonus %              971
# Senior Management      2
# Team                  10
# dtype: int64

# %%
type(employees)
# Out:
# pandas.core.frame.DataFrame

# %%
type(employees['Gender'])
# Out:
# pandas.core.series.Series

# %%
type(employees[['Gender']])
# Out:
# pandas.core.frame.DataFrame

# %%
employees["Gender"].unique()
# Out:
# ['Male', 'Female', NaN]
# Categories (2, object): ['Female', 'Male']

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 49.1+ KB

# %%
employees.nunique()
# Out:
# First Name           200
# Gender                 2
# Start Date           972
# Last Login Time      542
# Salary               995
# Bonus %              971
# Senior Management      2
# Team                  10
# dtype: int64

# %%
employees.nunique(dropna = False)
# Out:
# First Name           201
# Gender                 3
# Start Date           972
# Last Login Time      542
# Salary               995
# Bonus %              971
# Senior Management      2
# Team                  11
# dtype: int64

# %%
employees.shape
# Out:
# (1000, 8)

# %%
type(employees.shape)
# Out:
# tuple
